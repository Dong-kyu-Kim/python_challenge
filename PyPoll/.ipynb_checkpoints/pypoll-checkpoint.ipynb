# %%
import os
import csv

# Files to load and output
file_to_load=os.path.join(".","Resources","election_data.csv")
file_to_output=os.path.join(".","election_analysis.txt")

# Total vote counter
total_votes=0

# Candidate options and vote counters
candidate_votes={}
candidate_options=[]

# Winning candidate and winning count tracker
winning_candidate=""
wining_count=0

with open(file_to_load) as election_data:
    
    reader=csv.reader(election_data)
    header=next(reader)
    print(header)

    for row in reader:

        total_votes=total_votes+1
        print(row)

print(total_votes)
# Election Results
# -------------------------
# Total Votes: 369711
# -------------------------
# Charles Casper Stockham: 23.049% (85213)
# Diana DeGette: 73.812% (272892)
# Raymon Anthony Doane: 3.139% (11606)
# -------------------------
# Winner: Diana DeGette
# -------------------------
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ['6923771', 'Denver', 'Diana DeGette']
# ['5953663', 'Denver', 'Diana DeGette']
# ['7350737', 'Denver', 'Diana DeGette']
# ['7217159', 'Denver', 'Diana DeGette']
# ['5913678', 'Denver', 'Diana DeGette']
# ['5686334', 'Denver', 'Diana DeGette']
# ['6488276', 'Denver', 'Diana DeGette']
# ['5385468', 'Denver', 'Diana DeGette']
# ['7211350', 'Denver', 'Diana DeGette']
# ['6387811', 'Denver', 'Diana DeGette']
# ['7255844', 'Denver', 'Diana DeGette']
# ['7938204', 'Denver', 'Diana DeGette']
# ['7771527', 'Denver', 'Diana DeGette']
# ['6738707', 'Denver', 'Diana DeGette']
# ['6718099', 'Denver', 'Diana DeGette']
# ['7867257', 'Denver', 'Diana DeGette']
# ['6264689', 'Denver', 'Diana DeGette']
# ['5662823', 'Denver', 'Diana DeGette']
# ['6615644', 'Denver', 'Diana DeGette']
# ['7840287', 'Denver', 'Diana DeGette']
# ['5788636', 'Denver', 'Diana DeGette']
# ['5035759', 'Denver', 'Diana DeGette']
# ['5775103', 'Denver', 'Diana DeGette']
# ['7940139', 'Denver', 'Diana DeGette']
# ['5113360', 'Denver', 'Diana DeGette']
# ['7907605', 'Denver', 'Diana DeGette']
# ['6747682', 'Denver', 'Diana DeGette']
# ['5412081', 'Denver', 'Diana DeGette']
# ['5676720', 'Denver', 'Diana DeGette']
# ['5096612', 'Denver', 'Diana DeGette']
# ['5841821', 'Denver', 'Diana DeGette']
# ['6188559', 'Denver', 'Diana DeGette']
# ['6644786', 'Denver', 'Diana DeGette']
# ['6681202', 'Denver', 'Diana DeGette']
# ['7691324', 'Denver', 'Diana DeGette']
# ['5180988', 'Denver', 'Diana DeGette']
# ['7377145', 'Denver', 'Diana DeGette']
# ['5036989', 'Denver', 'Diana DeGette']
# ['5497570', 'Denver', 'Diana DeGette']
# ['6779443', 'Denver', 'Diana DeGette']
# ['6142247', 'Denver', 'Diana DeGette']
# ['5195548', 'Denver', 'Diana DeGette']
# ['6771936', 'Denver', 'Diana DeGette']
# ['6811697', 'Denver', 'Diana DeGette']
# ['6260646', 'Denver', 'Diana DeGette']
# ['6467660', 'Denver', 'Diana DeGette']
# ['6351875', 'Denver', 'Diana DeGette']
# ['5587117', 'Denver', 'Diana DeGette']
# ['6004171', 'Denver', 'Diana DeGette']
# ['5809782', 'Denver', 'Diana DeGette']
# ['7515387', 'Denver', 'Diana DeGette']
# ['6048617', 'Denver', 'Diana DeGette']
# ['5753713', 'Denver', 'Diana DeGette']
# ['5876831', 'Denver', 'Diana DeGette']
# ['6960310', 'Denver', 'Diana DeGette']
# ['5752944', 'Denver', 'Diana DeGette']
# ['6926985', 'Denver', 'Diana DeGette']
# ['6111553', 'Denver', 'Diana DeGette']
# ['5066658', 'Denver', 'Diana DeGette']
# ['7501059', 'Denver', 'Diana DeGette']
# ['7753036', 'Denver', 'Diana DeGette']
# ['5252093', 'Denver', 'Diana DeGette']
# ['5131140', 'Denver', 'Diana DeGette']
# ['6741291', 'Denver', 'Diana DeGette']
# ['5193369', 'Denver', 'Diana DeGette']
# ['6303386', 'Denver', 'Diana DeGette']
# ['5321048', 'Denver', 'Diana DeGette']
# ['7545418', 'Denver', 'Diana DeGette']
# ['7877999', 'Denver', 'Diana DeGette']
# ['6902231', 'Denver', 'Diana DeGette']
# ['6176642', 'Denver', 'Diana DeGette']
# ['6138123', 'Denver', 'Diana DeGette']
# ['6043437', 'Denver', 'Diana DeGette']
# ['7964121', 'Denver', 'Diana DeGette']
# ['7230769', 'Denver', 'Diana DeGette']
# ['6034755', 'Denver', 'Diana DeGette']
# ['5731853', 'Denver', 'Diana DeGette']
# ['5689642', 'Denver', 'Diana DeGette']
# ['5546292', 'Denver', 'Diana DeGette']
# ['5643061', 'Denver', 'Diana DeGette']
# ['6690598', 'Denver', 'Diana DeGette']
# ['7791765', 'Denver', 'Diana DeGette']
# ['6368732', 'Denver', 'Diana DeGette']
# ['6684456', 'Denver', 'Diana DeGette']
# ['7020308', 'Denver', 'Diana DeGette']
# ['7810603', 'Denver', 'Diana DeGette']
# ['5840393', 'Denver', 'Diana DeGette']
# ['7538198', 'Denver', 'Diana DeGette']
# ['7531148', 'Denver', 'Diana DeGette']
# ['7083662', 'Denver', 'Diana DeGette']
# ['7357230', 'Denver', 'Diana DeGette']
# ['7731145', 'Denver', 'Diana DeGette']
# ['7926341', 'Denver', 'Diana DeGette']
# ['5740735', 'Denver', 'Diana DeGette']
# ['6785576', 'Denver', 'Diana DeGette']
# ['7016447', 'Denver', 'Diana DeGette']
# ['5576559', 'Denver', 'Diana DeGette']
# ['5293651', 'Denver', 'Diana DeGette']
# ['5397592', 'Denver', 'Diana DeGette']
# ['6511271', 'Denver', 'Diana DeGette']
# ['7674741', 'Denver', 'Diana DeGette']
# ['7504628', 'Denver', 'Diana DeGette']
# ['6885306', 'Denver', 'Diana DeGette']
# ['7079927', 'Denver', 'Diana DeGette']
# ['7163008', 'Denver', 'Diana DeGette']
# ['6910716', 'Denver', 'Diana DeGette']
# ['5249887', 'Denver', 'Diana DeGette']
# ['6267599', 'Denver', 'Diana DeGette']
# ['7314386', 'Denver', 'Diana DeGette']
# ['6589306', 'Denver', 'Diana DeGette']
# ['6942679', 'Denver', 'Diana DeGette']
# ['5420968', 'Denver', 'Diana DeGette']
# ['6742585', 'Denver', 'Diana DeGette']
# ['6528655', 'Denver', 'Diana DeGette']
# ['6393534', 'Denver', 'Diana DeGette']
# ['6065868', 'Denver', 'Diana DeGette']
# ['5663530', 'Denver', 'Diana DeGette']
# ['5623552', 'Denver', 'Diana DeGette']
# ['7838757', 'Denver', 'Diana DeGette']
# ['5073248', 'Denver', 'Diana DeGette']
# ['6949754', 'Denver', 'Diana DeGette']
# ['5052200', 'Denver', 'Diana DeGette']
# ['5910780', 'Denver', 'Diana DeGette']
# ['7595860', 'Denver', 'Diana DeGette']
# ['7088328', 'Denver', 'Diana DeGette']
# ['5476438', 'Denver', 'Diana DeGette']
# ['5190305', 'Denver', 'Diana DeGette']
# ['7545005', 'Denver', 'Diana DeGette']
# ['6564614', 'Denver', 'Diana DeGette']
# ['6093391', 'Denver', 'Diana DeGette']
# ['7624995', 'Denver', 'Diana DeGette']
# ['6144236', 'Denver', 'Diana DeGette']
# ['7957847', 'Denver', 'Diana DeGette']
# ['5852782', 'Denver', 'Diana DeGette']
# ['6992055', 'Denver', 'Diana DeGette']
# ['7840382', 'Denver', 'Diana DeGette']
# ['7969724', 'Denver', 'Diana DeGette']
# ['5424878', 'Denver', 'Diana DeGette']
# ['6004391', 'Denver', 'Diana DeGette']
# ['7101007', 'Denver', 'Diana DeGette']
# ['7332765', 'Denver', 'Diana DeGette']
# ['6913477', 'Denver', 'Diana DeGette']
# ['5635659', 'Denver', 'Diana DeGette']
# ['6457488', 'Denver', 'Diana DeGette']
# ['5158853', 'Denver', 'Diana DeGette']
# ['5324596', 'Denver', 'Diana DeGette']
# ['7732489', 'Denver', 'Diana DeGette']
# ['7983367', 'Denver', 'Diana DeGette']
# ['6078101', 'Denver', 'Diana DeGette']
# ['6344107', 'Denver', 'Diana DeGette']
# ['7671326', 'Denver', 'Diana DeGette']
# ['7168531', 'Denver', 'Diana DeGette']
# ['6767236', 'Denver', 'Diana DeGette']
# ['5300024', 'Denver', 'Diana DeGette']
# ['5588810', 'Denver', 'Diana DeGette']
# ['5056657', 'Denver', 'Diana DeGette']
# ['5940555', 'Denver', 'Diana DeGette']
# ['7479664', 'Denver', 'Diana DeGette']
# ['7470717', 'Denver', 'Diana DeGette']
# ['7517317', 'Denver', 'Diana DeGette']
# ['7277956', 'Denver', 'Diana DeGette']
# ['5367708', 'Denver', 'Diana DeGette']
# ['7877364', 'Denver', 'Diana DeGette']
# ['7586455', 'Denver', 'Diana DeGette']
# ['6641525', 'Denver', 'Diana DeGette']
# ['5786255', 'Denver', 'Diana DeGette']
# ['6946097', 'Denver', 'Diana DeGette']
# ['7805838', 'Denver', 'Diana DeGette']
# ['7196740', 'Denver', 'Diana DeGette']
# ['7251364', 'Denver', 'Diana DeGette']
# ['5783022', 'Denver', 'Diana DeGette']
# ['5061565', 'Denver', 'Diana DeGette']
# ['6049477', 'Denver', 'Diana DeGette']
# ['6618535', 'Denver', 'Diana DeGette']
# ['6289671', 'Denver', 'Diana DeGette']
# ['7200548', 'Denver', 'Diana DeGette']
# ['5544914', 'Denver', 'Diana DeGette']
# ['5136592', 'Denver', 'Diana DeGette']
# ['5016959', 'Denver', 'Diana DeGette']
# ['7028874', 'Denver', 'Diana DeGette']
# ['6278694', 'Denver', 'Diana DeGette']
# ['6628028', 'Denver', 'Diana DeGette']
# ['7612972', 'Denver', 'Diana DeGette']
# ['5872552', 'Denver', 'Diana DeGette']
# ['6051672', 'Denver', 'Diana DeGette']
# ['6910682', 'Denver', 'Diana DeGette']
# ['5012346', 'Denver', 'Diana DeGette']
# ['6490257', 'Denver', 'Diana DeGette']
# ['7112955', 'Denver', 'Diana DeGette']
# ['7674763', 'Denver', 'Diana DeGette']
# ['7936367', 'Denver', 'Diana DeGette']
# ['6940118', 'Denver', 'Diana DeGette']
# ['5505236', 'Denver', 'Diana DeGette']
# ['5549028', 'Denver', 'Diana DeGette']
# ['6446693', 'Denver', 'Diana DeGette']
# ['7392399', 'Denver', 'Diana DeGette']
# ['6780169', 'Denver', 'Diana DeGette']
# ['6002232', 'Denver', 'Diana DeGette']
# ['6366771', 'Denver', 'Diana DeGette']
# ['7176329', 'Denver', 'Diana DeGette']
# ['7927923', 'Denver', 'Diana DeGette']
# ['7464426', 'Denver', 'Diana DeGette']
# ['7977124', 'Denver', 'Diana DeGette']
# ['5962920', 'Denver', 'Diana DeGette']
# ['5141636', 'Denver', 'Diana DeGette']
# ['6203674', 'Denver', 'Diana DeGette']
# ['5907878', 'Denver', 'Diana DeGette']
# ['5879868', 'Denver', 'Diana DeGette']
# ['7265453', 'Denver', 'Diana DeGette']
# ['5241016', 'Denver', 'Diana DeGette']
# ['6873005', 'Denver', 'Diana DeGette']
# ['5446989', 'Denver', 'Diana DeGette']
# ['6283622', 'Denver', 'Diana DeGette']
# ['6101584', 'Denver', 'Diana DeGette']
# ['6609793', 'Denver', 'Diana DeGette']
# ['5235208', 'Denver', 'Diana DeGette']
# ['5668450', 'Denver', 'Diana DeGette']
# ['7591209', 'Denver', 'Diana DeGette']
# ['6227803', 'Denver', 'Diana DeGette']
# ['6844935', 'Denver', 'Diana DeGette']
# ['5321089', 'Denver', 'Diana DeGette']
# ['7146154', 'Denver', 'Diana DeGette']
# ['7066488', 'Denver', 'Diana DeGette']
# ['6982814', 'Denver', 'Diana DeGette']
# ['5749566', 'Denver', 'Diana DeGette']
# ['7889509', 'Denver', 'Diana DeGette']
# ['6686063', 'Denver', 'Diana DeGette']
# ['7359251', 'Denver', 'Diana DeGette']
# ['6146062', 'Denver', 'Diana DeGette']
# ['6433436', 'Denver', 'Diana DeGette']
# ['5720943', 'Denver', 'Diana DeGette']
# ['7068935', 'Denver', 'Diana DeGette']
# ['6402033', 'Denver', 'Diana DeGette']
# ['7562462', 'Denver', 'Diana DeGette']
# ['7560757', 'Denver', 'Diana DeGette']
# ['5624431', 'Denver', 'Diana DeGette']
# ['7541292', 'Denver', 'Diana DeGette']
# ['5105213', 'Denver', 'Diana DeGette']
# ['6716361', 'Denver', 'Diana DeGette']
# ['7047257', 'Denver', 'Diana DeGette']
# ['5097978', 'Denver', 'Diana DeGette']
# ['5730573', 'Denver', 'Diana DeGette']
# ['6990836', 'Denver', 'Diana DeGette']
# ['7916312', 'Denver', 'Diana DeGette']
# ['5741879', 'Denver', 'Diana DeGette']
# ['6033724', 'Denver', 'Diana DeGette']
# ['7577325', 'Denver', 'Diana DeGette']
# ['5476171', 'Denver', 'Diana DeGette']
# ['7372882', 'Denver', 'Diana DeGette']
# ['5438947', 'Denver', 'Diana DeGette']
# ['7073562', 'Denver', 'Diana DeGette']
# ['6735361', 'Denver', 'Diana DeGette']
# ['7587442', 'Denver', 'Diana DeGette']
# ['6903024', 'Denver', 'Diana DeGette']
# ['6207114', 'Denver', 'Diana DeGette']
# ['7185716', 'Denver', 'Diana DeGette']
# ['6869207', 'Denver', 'Diana DeGette']
# ['6856827', 'Denver', 'Diana DeGette']
# ['7752062', 'Denver', 'Diana DeGette']
# ['5837090', 'Denver', 'Diana DeGette']
# ['6487908', 'Denver', 'Diana DeGette']
# ['7473499', 'Denver', 'Diana DeGette']
# ['6174029', 'Denver', 'Diana DeGette']
# ['6324195', 'Denver', 'Diana DeGette']
# ['6703146', 'Denver', 'Diana DeGette']
# ['5479514', 'Denver', 'Diana DeGette']
# ['6066279', 'Denver', 'Diana DeGette']
# ['5875613', 'Denver', 'Diana DeGette']
# ['7813313', 'Denver', 'Diana DeGette']
# ['7792665', 'Denver', 'Diana DeGette']
# ['6062892', 'Denver', 'Diana DeGette']
# ['7737895', 'Denver', 'Diana DeGette']
# ['5899248', 'Denver', 'Diana DeGette']
# ['5021074', 'Denver', 'Diana DeGette']
# ['5657413', 'Denver', 'Diana DeGette']
# ['6902662', 'Denver', 'Diana DeGette']
# ['7358500', 'Denver', 'Diana DeGette']
# ['5863437', 'Denver', 'Diana DeGette']
# ['5027321', 'Denver', 'Diana DeGette']
# ['6998773', 'Denver', 'Diana DeGette']
# ['5373467', 'Denver', 'Diana DeGette']
# ['5838729', 'Denver', 'Diana DeGette']
# ['6735319', 'Denver', 'Diana DeGette']
# ['5051802', 'Denver', 'Diana DeGette']
# ['7142298', 'Denver', 'Diana DeGette']
# ['5655888', 'Denver', 'Diana DeGette']
# ['7212577', 'Denver', 'Diana DeGette']
# ['7093177', 'Denver', 'Diana DeGette']
# ['6102306', 'Denver', 'Diana DeGette']
# ['7459464', 'Denver', 'Diana DeGette']
# ['5346334', 'Denver', 'Diana DeGette']
# ['5548256', 'Denver', 'Diana DeGette']
# ['6528815', 'Denver', 'Diana DeGette']
# ['5748285', 'Denver', 'Diana DeGette']
# ['5294581', 'Denver', 'Diana DeGette']
# ['6855353', 'Denver', 'Diana DeGette']
# ['7981568', 'Denver', 'Diana DeGette']
# ['7621694', 'Denver', 'Diana DeGette']
# ['5762984', 'Denver', 'Diana DeGette']
# ['6743545', 'Denver', 'Diana DeGette']
# ['5161808', 'Denver', 'Diana DeGette']
# ['7649625', 'Denver', 'Diana DeGette']
# ['6620629', 'Denver', 'Diana DeGette']
# ['6236617', 'Denver', 'Diana DeGette']
# ['6266243', 'Denver', 'Diana DeGette']
# ['7910254', 'Denver', 'Diana DeGette']
# ['6235401', 'Denver', 'Diana DeGette']
# ['6930386', 'Denver', 'Diana DeGette']
# ['7770458', 'Denver', 'Diana DeGette']
# ['5917872', 'Denver', 'Diana DeGette']
# ['6103190', 'Denver', 'Diana DeGette']
# ['7791331', 'Denver', 'Diana DeGette']
# ['5372290', 'Denver', 'Diana DeGette']
# ['5903647', 'Denver', 'Diana DeGette']
# ['7824398', 'Denver', 'Diana DeGette']
# ['5180107', 'Denver', 'Diana DeGette']
# ['7871103', 'Denver', 'Diana DeGette']
# ['5593269', 'Denver', 'Diana DeGette']
# ['6455611', 'Denver', 'Diana DeGette']
# ['6982955', 'Denver', 'Diana DeGette']
# ['5247009', 'Denver', 'Diana DeGette']
# ['7205288', 'Denver', 'Diana DeGette']
# ['7222980', 'Denver', 'Diana DeGette']
# ['7831137', 'Denver', 'Diana DeGette']
# ['6927921', 'Denver', 'Diana DeGette']
# ['6177298', 'Denver', 'Diana DeGette']
# ['7877770', 'Denver', 'Diana DeGette']
# ['6243372', 'Denver', 'Diana DeGette']
# ['6821525', 'Denver', 'Diana DeGette']
# ['5298335', 'Denver', 'Diana DeGette']
# ['5034369', 'Denver', 'Diana DeGette']
# ['5931328', 'Denver', 'Diana DeGette']
# ['7032578', 'Denver', 'Diana DeGette']
# ['7220831', 'Denver', 'Diana DeGette']
# ['7652304', 'Denver', 'Diana DeGette']
# ['7811270', 'Denver', 'Diana DeGette']
# ['6260846', 'Denver', 'Diana DeGette']
# ['6520233', 'Denver', 'Diana DeGette']
# ['6210624', 'Denver', 'Diana DeGette']
# ['7896764', 'Denver', 'Diana DeGette']
# ['7410036', 'Denver', 'Diana DeGette']
# ['5492078', 'Denver', 'Diana DeGette']
# ['6080122', 'Denver', 'Diana DeGette']
# ['6038713', 'Denver', 'Diana DeGette']
# ['5456217', 'Denver', 'Diana DeGette']
# ['7401003', 'Denver', 'Diana DeGette']
# ['7682759', 'Denver', 'Diana DeGette']
# ['5298084', 'Denver', 'Diana DeGette']
# ['7524289', 'Denver', 'Diana DeGette']
# ['5199686', 'Denver', 'Diana DeGette']
# ['7740417', 'Denver', 'Diana DeGette']
# ['6182308', 'Denver', 'Diana DeGette']
# ['6859940', 'Denver', 'Diana DeGette']
# ['7127785', 'Denver', 'Diana DeGette']
# ['6764185', 'Denver', 'Diana DeGette']
# ['7541074', 'Denver', 'Diana DeGette']
# ['5705473', 'Denver', 'Diana DeGette']
# ['6488295', 'Denver', 'Diana DeGette']
# ['7454511', 'Denver', 'Diana DeGette']
# ['5345584', 'Denver', 'Diana DeGette']
# ['7988213', 'Denver', 'Diana DeGette']
# ['5293951', 'Denver', 'Diana DeGette']
# ['5248007', 'Denver', 'Diana DeGette']
# ['7228860', 'Denver', 'Diana DeGette']
# ['7787498', 'Denver', 'Diana DeGette']
# ['7669742', 'Denver', 'Diana DeGette']
# ['6999875', 'Denver', 'Diana DeGette']
# ['7174894', 'Denver', 'Diana DeGette']
# ['7180499', 'Denver', 'Diana DeGette']
# ['7938995', 'Denver', 'Diana DeGette']
# ['5123479', 'Denver', 'Diana DeGette']
# ['7590717', 'Denver', 'Diana DeGette']
# ['5030597', 'Denver', 'Diana DeGette']
# ['7403848', 'Denver', 'Diana DeGette']
# ['7736155', 'Denver', 'Diana DeGette']
# ['6070102', 'Denver', 'Diana DeGette']
# ['7048071', 'Denver', 'Diana DeGette']
# ['5574280', 'Denver', 'Diana DeGette']
# ['5439337', 'Denver', 'Diana DeGette']
# ['6621881', 'Denver', 'Diana DeGette']
# ['5765367', 'Denver', 'Diana DeGette']
# ['5695374', 'Denver', 'Diana DeGette']
# ['5888778', 'Denver', 'Diana DeGette']
# ['5926287', 'Denver', 'Diana DeGette']
# ['6340926', 'Denver', 'Diana DeGette']
# ['7898977', 'Denver', 'Diana DeGette']
# ['5568651', 'Denver', 'Diana DeGette']
# ['7764364', 'Denver', 'Diana DeGette']
# ['5857608', 'Denver', 'Diana DeGette']
# ['7851824', 'Denver', 'Diana DeGette']
# ['7486071', 'Denver', 'Diana DeGette']
# ['7594045', 'Denver', 'Diana DeGette']
# ['7829802', 'Denver', 'Diana DeGette']
# ['5638161', 'Denver', 'Diana DeGette']
# ['7358866', 'Denver', 'Diana DeGette']
# ['7769365', 'Denver', 'Diana DeGette']
# ['6731656', 'Denver', 'Diana DeGette']
# ['7877352', 'Denver', 'Diana DeGette']
# ['5804965', 'Denver', 'Diana DeGette']
# ['6251901', 'Denver', 'Diana DeGette']
# ['6618106', 'Denver', 'Diana DeGette']
# ['6364859', 'Denver', 'Diana DeGette']
# ['6696311', 'Denver', 'Diana DeGette']
# ['6624307', 'Denver', 'Diana DeGette']
# ['6142359', 'Denver', 'Diana DeGette']
# ['7140140', 'Denver', 'Diana DeGette']
# ['5504346', 'Denver', 'Diana DeGette']
# ['6136740', 'Denver', 'Diana DeGette']
# ['7138618', 'Denver', 'Diana DeGette']
# ['6342693', 'Denver', 'Diana DeGette']
# ['5325499', 'Denver', 'Diana DeGette']
# ['5283544', 'Denver', 'Diana DeGette']
# ['6859144', 'Denver', 'Diana DeGette']
# ['5801389', 'Denver', 'Diana DeGette']
# ['7602170', 'Denver', 'Diana DeGette']
# ['7355558', 'Denver', 'Diana DeGette']
# ['5101530', 'Denver', 'Diana DeGette']
# ['7439752', 'Denver', 'Diana DeGette']
# ['7283732', 'Denver', 'Diana DeGette']
# ['7263142', 'Denver', 'Diana DeGette']
# ['6999448', 'Denver', 'Diana DeGette']
# ['6716935', 'Denver', 'Diana DeGette']
# ['5302063', 'Denver', 'Diana DeGette']
# ['6022247', 'Denver', 'Diana DeGette']
# ['7125823', 'Denver', 'Diana DeGette']
# ['5520235', 'Denver', 'Diana DeGette']
# ['5196287', 'Denver', 'Diana DeGette']
# ['6949407', 'Denver', 'Diana DeGette']
# ['6194548', 'Denver', 'Diana DeGette']
# ['5385477', 'Denver', 'Diana DeGette']
# ['5557602', 'Denver', 'Diana DeGette']
# ['6138807', 'Denver', 'Diana DeGette']
# ['7790749', 'Denver', 'Diana DeGette']
# ['6338095', 'Denver', 'Diana DeGette']
# ['7963150', 'Denver', 'Diana DeGette']
# ['6032392', 'Denver', 'Diana DeGette']
# ['5038475', 'Denver', 'Diana DeGette']
# ['6644639', 'Denver', 'Diana DeGette']
# ['5307350', 'Denver', 'Diana DeGette']
# ['6698588', 'Denver', 'Diana DeGette']
# ['5538419', 'Denver', 'Diana DeGette']
# ['6416017', 'Denver', 'Diana DeGette']
# ['7343765', 'Denver', 'Diana DeGette']
# ['5568466', 'Denver', 'Diana DeGette']
# ['5123948', 'Denver', 'Diana DeGette']
# ['6647047', 'Denver', 'Diana DeGette']
# ['7398439', 'Denver', 'Diana DeGette']
# ['7684413', 'Denver', 'Diana DeGette']
# ['5480267', 'Denver', 'Diana DeGette']
# ['5323185', 'Denver', 'Diana DeGette']
# ['7051315', 'Denver', 'Diana DeGette']
# ['7461362', 'Denver', 'Diana DeGette']
# ['7991556', 'Denver', 'Diana DeGette']
# ['6876431', 'Denver', 'Diana DeGette']
# ['6132580', 'Denver', 'Diana DeGette']
# ['7416241', 'Denver', 'Diana DeGette']
# ['6423453', 'Denver', 'Diana DeGette']
# ['6044941', 'Denver', 'Diana DeGette']
# ['7155725', 'Denver', 'Diana DeGette']
# ['6120970', 'Denver', 'Diana DeGette']
# ['5543469', 'Denver', 'Diana DeGette']
# ['5456320', 'Denver', 'Diana DeGette']
# ['5614070', 'Denver', 'Diana DeGette']
# ['6304644', 'Denver', 'Diana DeGette']
# ['7735478', 'Denver', 'Diana DeGette']
# ['6304348', 'Denver', 'Diana DeGette']
# ['7956291', 'Denver', 'Diana DeGette']
# ['6544284', 'Denver', 'Diana DeGette']
# ['5059414', 'Denver', 'Diana DeGette']
# ['6169472', 'Denver', 'Diana DeGette']
# ['5950472', 'Denver', 'Diana DeGette']
# ['6502621', 'Denver', 'Diana DeGette']
# ['6345466', 'Denver', 'Diana DeGette']
# ['6591311', 'Denver', 'Diana DeGette']
# ['6032199', 'Denver', 'Diana DeGette']
# ['6839353', 'Denver', 'Diana DeGette']
# ['5906422', 'Denver', 'Diana DeGette']
# ['6882023', 'Denver', 'Diana DeGette']
# ['5129002', 'Denver', 'Diana DeGette']
# ['5544972', 'Denver', 'Diana DeGette']
# ['6479268', 'Denver', 'Diana DeGette']
# ['6325933', 'Denver', 'Diana DeGette']
# ['7407093', 'Denver', 'Diana DeGette']
# ['7547244', 'Denver', 'Diana DeGette']
# ['7302179', 'Denver', 'Diana DeGette']
# ['6891126', 'Denver', 'Diana DeGette']
# ['5658076', 'Denver', 'Diana DeGette']
# ['6082754', 'Denver', 'Diana DeGette']
# ['7035566', 'Denver', 'Diana DeGette']
# ['7093496', 'Denver', 'Diana DeGette']
# ['6983190', 'Denver', 'Diana DeGette']
# ['6097407', 'Denver', 'Diana DeGette']
# ['6822235', 'Denver', 'Diana DeGette']
# ['6402454', 'Denver', 'Diana DeGette']
# ['7930240', 'Denver', 'Diana DeGette']
# ['6933445', 'Denver', 'Diana DeGette']
# ['5247105', 'Denver', 'Diana DeGette']
# ['7408263', 'Denver', 'Diana DeGette']
# ['7596035', 'Denver', 'Diana DeGette']
# ['6211893', 'Denver', 'Diana DeGette']
# ['6467120', 'Denver', 'Diana DeGette']
# ['7159032', 'Denver', 'Diana DeGette']
# ['6140626', 'Denver', 'Diana DeGette']
# ['7018481', 'Denver', 'Diana DeGette']
# ['5392172', 'Denver', 'Diana DeGette']
# ['7624888', 'Denver', 'Diana DeGette']
# ['6879338', 'Denver', 'Diana DeGette']
# ['6285897', 'Denver', 'Diana DeGette']
# ['7439041', 'Denver', 'Diana DeGette']
# ['6354954', 'Denver', 'Diana DeGette']
# ['7951006', 'Denver', 'Diana DeGette']
# ['7409665', 'Denver', 'Diana DeGette']
# ['6241952', 'Denver', 'Diana DeGette']
# ['7855202', 'Denver', 'Diana DeGette']
# ['5886415', 'Denver', 'Diana DeGette']
# ['6926342', 'Denver', 'Diana DeGette']
# ['7537816', 'Denver', 'Diana DeGette']
# ['7886702', 'Denver', 'Diana DeGette']
# ['5942624', 'Denver', 'Diana DeGette']
# ['5143465', 'Denver', 'Diana DeGette']
# ['7860397', 'Denver', 'Diana DeGette']
# ['5722760', 'Denver', 'Diana DeGette']
# ['6231844', 'Denver', 'Diana DeGette']
# ['6703393', 'Denver', 'Diana DeGette']
# ['6437341', 'Denver', 'Diana DeGette']
# ['5419662', 'Denver', 'Diana DeGette']
# ['6797679', 'Denver', 'Diana DeGette']
# ['6166684', 'Denver', 'Diana DeGette']
# ['5930027', 'Denver', 'Diana DeGette']
# ['5779640', 'Denver', 'Diana DeGette']
# ['6275476', 'Denver', 'Diana DeGette']
# ['7556123', 'Denver', 'Diana DeGette']
# ['6245600', 'Denver', 'Diana DeGette']
# ['5579178', 'Denver', 'Diana DeGette']
# ['5458774', 'Denver', 'Diana DeGette']
# ['5391431', 'Denver', 'Diana DeGette']
# ['5715141', 'Denver', 'Diana DeGette']
# ['7878512', 'Denver', 'Diana DeGette']
# ['7292541', 'Denver', 'Diana DeGette']
# ['6199277', 'Denver', 'Diana DeGette']
# ['5085968', 'Denver', 'Diana DeGette']
# ['5985988', 'Denver', 'Diana DeGette']
# ['6719311', 'Denver', 'Diana DeGette']
# ['6541912', 'Denver', 'Diana DeGette']
# ['5845091', 'Denver', 'Diana DeGette']
# ['5325344', 'Denver', 'Diana DeGette']
# ['7224922', 'Denver', 'Diana DeGette']
# ['6854501', 'Denver', 'Diana DeGette']
# ['7502115', 'Denver', 'Diana DeGette']
# ['5015169', 'Denver', 'Diana DeGette']
# ['6199544', 'Denver', 'Diana DeGette']
# ['6774592', 'Denver', 'Diana DeGette']
# ['6151602', 'Denver', 'Diana DeGette']
# ['7468664', 'Denver', 'Diana DeGette']
# ['7274048', 'Denver', 'Diana DeGette']
# ['7494706', 'Denver', 'Diana DeGette']
# ['7275977', 'Denver', 'Diana DeGette']
# ['7534075', 'Denver', 'Diana DeGette']
# ['6342951', 'Denver', 'Diana DeGette']
# ['6820551', 'Denver', 'Diana DeGette']
# ['7982443', 'Denver', 'Diana DeGette']
# ['7715445', 'Denver', 'Diana DeGette']
# ['5949976', 'Denver', 'Diana DeGette']
# ['7547636', 'Denver', 'Diana DeGette']
# ['5778524', 'Denver', 'Diana DeGette']
# ['5479945', 'Denver', 'Diana DeGette']
# ['5423750', 'Denver', 'Diana DeGette']
# ['7331736', 'Denver', 'Diana DeGette']
# ['5998331', 'Denver', 'Diana DeGette']
# ['5361035', 'Denver', 'Diana DeGette']
# ['5243672', 'Denver', 'Diana DeGette']
# ['7843974', 'Denver', 'Diana DeGette']
# ['6553080', 'Denver', 'Diana DeGette']
# ['6719780', 'Denver', 'Diana DeGette']
# ['7987139', 'Denver', 'Diana DeGette']
# ['6614626', 'Denver', 'Diana DeGette']
# ['5507763', 'Denver', 'Diana DeGette']
# ['6393796', 'Denver', 'Diana DeGette']
# ['5839011', 'Denver', 'Diana DeGette']
# ['6340114', 'Denver', 'Diana DeGette']
# ['5461275', 'Denver', 'Diana DeGette']
# ['7125331', 'Denver', 'Diana DeGette']
# ['6164002', 'Denver', 'Diana DeGette']
# ['7837978', 'Denver', 'Diana DeGette']
# ['7137401', 'Denver', 'Diana DeGette']
# ['6384194', 'Denver', 'Diana DeGette']
# ['6588685', 'Denver', 'Diana DeGette']
# ['5506268', 'Denver', 'Diana DeGette']
# ['6212871', 'Denver', 'Diana DeGette']
# ['6972517', 'Denver', 'Diana DeGette']
# ['6335264', 'Denver', 'Diana DeGette']
# ['5066625', 'Denver', 'Diana DeGette']
# ['7034655', 'Denver', 'Diana DeGette']
# ['6620054', 'Denver', 'Diana DeGette']
# ['6963316', 'Denver', 'Diana DeGette']
# ['7204686', 'Denver', 'Diana DeGette']
# ['6261155', 'Denver', 'Diana DeGette']
# ['6707412', 'Denver', 'Diana DeGette']
# ['6080948', 'Denver', 'Diana DeGette']
# ['6215287', 'Denver', 'Diana DeGette']
# ['6522477', 'Denver', 'Diana DeGette']
# ['6444904', 'Denver', 'Diana DeGette']
# ['7910898', 'Denver', 'Diana DeGette']
# ['7003581', 'Denver', 'Diana DeGette']
# ['6984990', 'Denver', 'Diana DeGette']
# ['5660520', 'Denver', 'Diana DeGette']
# ['7379399', 'Denver', 'Diana DeGette']
# ['6476875', 'Denver', 'Diana DeGette']
# ['7260813', 'Denver', 'Diana DeGette']
# ['5720126', 'Denver', 'Diana DeGette']
# ['7677644', 'Denver', 'Diana DeGette']
# ['6650324', 'Denver', 'Diana DeGette']
# ['5449631', 'Denver', 'Diana DeGette']
# ['7453365', 'Denver', 'Diana DeGette']
# ['7508862', 'Denver', 'Diana DeGette']
# ['5949432', 'Denver', 'Diana DeGette']
# ['7851305', 'Denver', 'Diana DeGette']
# ['7030046', 'Denver', 'Diana DeGette']
# ['6687244', 'Denver', 'Diana DeGette']
# ['7281424', 'Denver', 'Diana DeGette']
# ['6909629', 'Denver', 'Diana DeGette']
# ['6080327', 'Denver', 'Diana DeGette']
# ['7434526', 'Denver', 'Diana DeGette']
# ['7665986', 'Denver', 'Diana DeGette']
# ['5111508', 'Denver', 'Diana DeGette']
# ['5226221', 'Denver', 'Diana DeGette']
# ['7842119', 'Denver', 'Diana DeGette']
# ['7074549', 'Denver', 'Diana DeGette']
# ['6217680', 'Denver', 'Diana DeGette']
# ['5634520', 'Denver', 'Diana DeGette']
# ['7348451', 'Denver', 'Diana DeGette']
# ['7331863', 'Denver', 'Diana DeGette']
# ['5963679', 'Denver', 'Diana DeGette']
# ['6689846', 'Denver', 'Diana DeGette']
# ['5430719', 'Denver', 'Diana DeGette']
# ['7413378', 'Denver', 'Diana DeGette']
# ['7318096', 'Denver', 'Diana DeGette']
# ['5647839', 'Denver', 'Diana DeGette']
# ['7150694', 'Denver', 'Diana DeGette']
# ['7542418', 'Denver', 'Diana DeGette']
# ['7007289', 'Denver', 'Diana DeGette']
# ['7432802', 'Denver', 'Diana DeGette']
# ['5437832', 'Denver', 'Diana DeGette']
# ['5269202', 'Denver', 'Diana DeGette']
# ['7550183', 'Denver', 'Diana DeGette']
# ['5588229', 'Denver', 'Diana DeGette']
# ['6720476', 'Denver', 'Diana DeGette']
# ['6717194', 'Denver', 'Diana DeGette']
# ['5404741', 'Denver', 'Diana DeGette']
# ['6127708', 'Denver', 'Diana DeGette']
# ['5123977', 'Denver', 'Diana DeGette']
# ['6588174', 'Denver', 'Diana DeGette']
# ['5930765', 'Denver', 'Diana DeGette']
# ['6056375', 'Denver', 'Diana DeGette']
# ['6553028', 'Denver', 'Diana DeGette']
# ['7240183', 'Denver', 'Diana DeGette']
# ['5183724', 'Denver', 'Diana DeGette']
# ['7381916', 'Denver', 'Diana DeGette']
# ['5636834', 'Denver', 'Diana DeGette']
# ['7210589', 'Denver', 'Diana DeGette']
# ['5760651', 'Denver', 'Diana DeGette']
# ['6747644', 'Denver', 'Diana DeGette']
# ['5523822', 'Denver', 'Diana DeGette']
# ['6751926', 'Denver', 'Diana DeGette']
# ['7418885', 'Denver', 'Diana DeGette']
# ['6958152', 'Denver', 'Diana DeGette']
# ['7203832', 'Denver', 'Diana DeGette']
# ['7418762', 'Denver', 'Diana DeGette']
# ['7891056', 'Denver', 'Diana DeGette']
# ['6743833', 'Denver', 'Diana DeGette']
# ['7850803', 'Denver', 'Diana DeGette']
# ['5729540', 'Denver', 'Diana DeGette']
# ['5234362', 'Denver', 'Diana DeGette']
# ['5905326', 'Denver', 'Diana DeGette']
# ['7920877', 'Denver', 'Diana DeGette']
# ['5248160', 'Denver', 'Diana DeGette']
# ['6257545', 'Denver', 'Diana DeGette']
# ['5216003', 'Denver', 'Diana DeGette']
# ['5466453', 'Denver', 'Diana DeGette']
# ['6885381', 'Denver', 'Diana DeGette']
# ['6488089', 'Denver', 'Diana DeGette']
# ['6986014', 'Denver', 'Diana DeGette']
# ['6959074', 'Denver', 'Diana DeGette']
# ['5726785', 'Denver', 'Diana DeGette']
# ['6652905', 'Denver', 'Diana DeGette']
# ['6601775', 'Denver', 'Diana DeGette']
# ['7585428', 'Denver', 'Diana DeGette']
# ['5982004', 'Denver', 'Diana DeGette']
# ['6616833', 'Denver', 'Diana DeGette']
# ['6060470', 'Denver', 'Diana DeGette']
# ['5349254', 'Denver', 'Diana DeGette']
# ['5714507', 'Denver', 'Diana DeGette']
# ['6209266', 'Denver', 'Diana DeGette']
# ['7789220', 'Denver', 'Diana DeGette']
# ['7098661', 'Denver', 'Diana DeGette']
# ['5012399', 'Denver', 'Diana DeGette']
# ['6234050', 'Denver', 'Diana DeGette']
# ['5272177', 'Denver', 'Diana DeGette']
# ['7689167', 'Denver', 'Diana DeGette']
# ['7599453', 'Denver', 'Diana DeGette']
# ['5586566', 'Denver', 'Diana DeGette']
# ['6449813', 'Denver', 'Diana DeGette']
# ['6488014', 'Denver', 'Diana DeGette']
# ['6069484', 'Denver', 'Diana DeGette']
# ['6709344', 'Denver', 'Diana DeGette']
# ['6138468', 'Denver', 'Diana DeGette']
# ['5027429', 'Denver', 'Diana DeGette']
# ['7707925', 'Denver', 'Diana DeGette']
# ['7527124', 'Denver', 'Diana DeGette']
# ['6645353', 'Denver', 'Diana DeGette']
# ['5364907', 'Denver', 'Diana DeGette']
# ['6943547', 'Denver', 'Diana DeGette']
# ['5431303', 'Denver', 'Diana DeGette']
# ['6948621', 'Denver', 'Diana DeGette']
# ['5069712', 'Denver', 'Diana DeGette']
# ['5664334', 'Denver', 'Diana DeGette']
# ['6888060', 'Denver', 'Diana DeGette']
# ['7038531', 'Denver', 'Diana DeGette']
# ['5916835', 'Denver', 'Diana DeGette']
# ['7237300', 'Denver', 'Diana DeGette']
# ['5218506', 'Denver', 'Diana DeGette']
# ['7578210', 'Denver', 'Diana DeGette']
# ['7265178', 'Denver', 'Diana DeGette']
# ['6580548', 'Denver', 'Diana DeGette']
# ['6037360', 'Denver', 'Diana DeGette']
# ['7468418', 'Denver', 'Diana DeGette']
# ['7966585', 'Denver', 'Diana DeGette']
# ['7093767', 'Denver', 'Diana DeGette']
# ['7051556', 'Denver', 'Diana DeGette']
# ['5894822', 'Denver', 'Diana DeGette']
# ['7242218', 'Denver', 'Diana DeGette']
# ['7214144', 'Denver', 'Diana DeGette']
# ['7753326', 'Denver', 'Diana DeGette']
# ['7141692', 'Denver', 'Diana DeGette']
# ['6355247', 'Denver', 'Diana DeGette']
# ['6390996', 'Denver', 'Diana DeGette']
# ['6339277', 'Denver', 'Diana DeGette']
# ['6103686', 'Denver', 'Diana DeGette']
# ['5943610', 'Denver', 'Diana DeGette']
# ['5045019', 'Denver', 'Diana DeGette']
# ['7394222', 'Denver', 'Diana DeGette']
# ['6212061', 'Denver', 'Diana DeGette']
# ['6395627', 'Denver', 'Diana DeGette']
# ['6619184', 'Denver', 'Diana DeGette']
# ['7869804', 'Denver', 'Diana DeGette']
# ['6602072', 'Denver', 'Diana DeGette']
# ['7812139', 'Denver', 'Diana DeGette']
# ['5215829', 'Denver', 'Diana DeGette']
# ['5462973', 'Denver', 'Diana DeGette']
# ['6693114', 'Denver', 'Diana DeGette']
# ['7141793', 'Denver', 'Diana DeGette']
# ['5348027', 'Denver', 'Diana DeGette']
# ['7247915', 'Denver', 'Diana DeGette']
# ['7672379', 'Denver', 'Diana DeGette']
# ['6987976', 'Denver', 'Diana DeGette']
# ['5458996', 'Denver', 'Diana DeGette']
# ['6549094', 'Denver', 'Diana DeGette']
# ['7063096', 'Denver', 'Diana DeGette']
# ['6848004', 'Denver', 'Diana DeGette']
# ['5890386', 'Denver', 'Diana DeGette']
# ['7951469', 'Denver', 'Diana DeGette']
# ['7181253', 'Denver', 'Diana DeGette']
# ['6155101', 'Denver', 'Diana DeGette']
# ['6565510', 'Denver', 'Diana DeGette']
# ['7373897', 'Denver', 'Diana DeGette']
# ['7991533', 'Denver', 'Diana DeGette']
# ['6722543', 'Denver', 'Diana DeGette']
# ['7863070', 'Denver', 'Diana DeGette']
# ['7615666', 'Denver', 'Diana DeGette']
# ['5994977', 'Denver', 'Diana DeGette']
# ['5794124', 'Denver', 'Diana DeGette']
# ['5739898', 'Denver', 'Diana DeGette']
# ['5035785', 'Denver', 'Diana DeGette']
# ['7189559', 'Denver', 'Diana DeGette']
# ['7086326', 'Denver', 'Diana DeGette']
# ['6229279', 'Denver', 'Diana DeGette']
# ['7246357', 'Denver', 'Diana DeGette']
# ['6937270', 'Denver', 'Diana DeGette']
# ['7759817', 'Denver', 'Diana DeGette']
# ['5095899', 'Denver', 'Diana DeGette']
# ['6881854', 'Denver', 'Diana DeGette']
# ['7183781', 'Denver', 'Diana DeGette']
# ['6835931', 'Denver', 'Diana DeGette']
# ['7311711', 'Denver', 'Diana DeGette']
# ['5096091', 'Denver', 'Diana DeGette']
# ['7924962', 'Denver', 'Diana DeGette']
# ['6260511', 'Denver', 'Diana DeGette']
# ['7519684', 'Denver', 'Diana DeGette']
# ['5426850', 'Denver', 'Diana DeGette']
# ['5434289', 'Denver', 'Diana DeGette']
# ['7721491', 'Denver', 'Diana DeGette']
# ['7023353', 'Denver', 'Diana DeGette']
# ['6332531', 'Denver', 'Diana DeGette']
# ['6022122', 'Denver', 'Diana DeGette']
# ['7733106', 'Denver', 'Diana DeGette']
# ['7384977', 'Denver', 'Diana DeGette']
# ['7542242', 'Denver', 'Diana DeGette']
# ['7346209', 'Denver', 'Diana DeGette']
# ['6568410', 'Denver', 'Diana DeGette']
# ['6899726', 'Denver', 'Diana DeGette']
# ['7536939', 'Denver', 'Diana DeGette']
# ['7353337', 'Denver', 'Diana DeGette']
# ['6718111', 'Denver', 'Diana DeGette']
# ['6990884', 'Denver', 'Diana DeGette']
# ['6752004', 'Denver', 'Diana DeGette']
# ['7671796', 'Denver', 'Diana DeGette']
# ['5590686', 'Denver', 'Diana DeGette']
# ['6210125', 'Denver', 'Diana DeGette']
# ['6147912', 'Denver', 'Diana DeGette']
# ['7408624', 'Denver', 'Diana DeGette']
# ['6524810', 'Denver', 'Diana DeGette']
# ['6782810', 'Denver', 'Diana DeGette']
# ['7410524', 'Denver', 'Diana DeGette']
# ['5982544', 'Denver', 'Diana DeGette']
# ['5586631', 'Denver', 'Diana DeGette']
# ['7980755', 'Denver', 'Diana DeGette']
# ['5573965', 'Denver', 'Diana DeGette']
# ['5133824', 'Denver', 'Diana DeGette']
# ['5323985', 'Denver', 'Diana DeGette']
# ['6116498', 'Denver', 'Diana DeGette']
# ['6370332', 'Denver', 'Diana DeGette']
# ['6696668', 'Denver', 'Diana DeGette']
# ['6367085', 'Denver', 'Diana DeGette']
# ['5023175', 'Denver', 'Diana DeGette']
# ['6049263', 'Denver', 'Diana DeGette']
# ['5328089', 'Denver', 'Diana DeGette']
# ['7021147', 'Denver', 'Diana DeGette']
# ['6403753', 'Denver', 'Diana DeGette']
# ['5949239', 'Denver', 'Diana DeGette']
# ['6325298', 'Denver', 'Diana DeGette']
# ['7331784', 'Denver', 'Diana DeGette']
# ['5319278', 'Denver', 'Diana DeGette']
# ['5312444', 'Denver', 'Diana DeGette']
# ['5344844', 'Denver', 'Diana DeGette']
# ['7772113', 'Denver', 'Diana DeGette']
# ['7205876', 'Denver', 'Diana DeGette']
# ['6895559', 'Denver', 'Diana DeGette']
# ['7599708', 'Denver', 'Diana DeGette']
# ['7574350', 'Denver', 'Diana DeGette']
# ['6357304', 'Denver', 'Diana DeGette']
# ['6475748', 'Denver', 'Diana DeGette']
# ['5412735', 'Denver', 'Diana DeGette']
# ['5512806', 'Denver', 'Diana DeGette']
# ['6876321', 'Denver', 'Diana DeGette']
# ['7884284', 'Denver', 'Diana DeGette']
# ['7923717', 'Denver', 'Diana DeGette']
# ['7702263', 'Denver', 'Diana DeGette']
# ['5944028', 'Denver', 'Diana DeGette']
# ['5045091', 'Denver', 'Diana DeGette']
# ['5588040', 'Denver', 'Diana DeGette']
# ['5603621', 'Denver', 'Diana DeGette']
# ['5332478', 'Denver', 'Diana DeGette']
# ['5747667', 'Denver', 'Diana DeGette']
# ['7382430', 'Denver', 'Diana DeGette']
# ['5298509', 'Denver', 'Diana DeGette']
# ['5157098', 'Denver', 'Diana DeGette']
# ['6318671', 'Denver', 'Diana DeGette']
# ['7738789', 'Denver', 'Diana DeGette']
# ['5264997', 'Denver', 'Diana DeGette']
# ['5316582', 'Denver', 'Diana DeGette']
# ['6080245', 'Denver', 'Diana DeGette']
# ['6912673', 'Denver', 'Diana DeGette']
# ['6282163', 'Denver', 'Diana DeGette']
# ['6390527', 'Denver', 'Diana DeGette']
# ['7003479', 'Denver', 'Diana DeGette']
# ['6116267', 'Denver', 'Diana DeGette']
# ['5111995', 'Denver', 'Diana DeGette']
# ['6263483', 'Denver', 'Diana DeGette']
# ['7440238', 'Denver', 'Diana DeGette']
# ['5627827', 'Denver', 'Diana DeGette']
# ['6929373', 'Denver', 'Diana DeGette']
# ['6053330', 'Denver', 'Diana DeGette']
# ['6124604', 'Denver', 'Diana DeGette']
# ['7177627', 'Denver', 'Diana DeGette']
# ['6592760', 'Denver', 'Diana DeGette']
# ['6626964', 'Denver', 'Diana DeGette']
# ['6480548', 'Denver', 'Diana DeGette']
# ['7364189', 'Denver', 'Diana DeGette']
# ['5563708', 'Denver', 'Diana DeGette']
# ['5277732', 'Denver', 'Diana DeGette']
# ['5890676', 'Denver', 'Diana DeGette']
# ['6619511', 'Denver', 'Diana DeGette']
# ['7246124', 'Denver', 'Diana DeGette']
# ['6119720', 'Denver', 'Diana DeGette']
# ['6626723', 'Denver', 'Diana DeGette']
# ['7282190', 'Denver', 'Diana DeGette']
# ['7006309', 'Denver', 'Diana DeGette']
# ['6299673', 'Denver', 'Diana DeGette']
# ['7695839', 'Denver', 'Diana DeGette']
# ['5818606', 'Denver', 'Diana DeGette']
# ['6473178', 'Denver', 'Diana DeGette']
# ['6911804', 'Denver', 'Diana DeGette']
# ['5543800', 'Denver', 'Diana DeGette']
# ['7452405', 'Denver', 'Diana DeGette']
# ['7479816', 'Denver', 'Diana DeGette']
# ['7631736', 'Denver', 'Diana DeGette']
# ['7044397', 'Denver', 'Diana DeGette']
# ['5755437', 'Denver', 'Diana DeGette']
# ['7124714', 'Denver', 'Diana DeGette']
# ['7239347', 'Denver', 'Diana DeGette']
# ['6315577', 'Denver', 'Diana DeGette']
# ['5454771', 'Denver', 'Diana DeGette']
# ['5069289', 'Denver', 'Diana DeGette']
# ['7835536', 'Denver', 'Diana DeGette']
# ['6553344', 'Denver', 'Diana DeGette']
# ['6382310', 'Denver', 'Diana DeGette']
# ['7546613', 'Denver', 'Diana DeGette']
# ['5905070', 'Denver', 'Diana DeGette']
# ['7381226', 'Denver', 'Diana DeGette']
# ['5108376', 'Denver', 'Diana DeGette']
# ['7198896', 'Denver', 'Diana DeGette']
# ['5174281', 'Denver', 'Diana DeGette']
# ['5856358', 'Denver', 'Diana DeGette']
# ['7889943', 'Denver', 'Diana DeGette']
# ['5620618', 'Denver', 'Diana DeGette']
# ['5624043', 'Denver', 'Diana DeGette']
# ['6901239', 'Denver', 'Diana DeGette']
# ['5460019', 'Denver', 'Diana DeGette']
# ['5121031', 'Denver', 'Diana DeGette']
# ['6824639', 'Denver', 'Diana DeGette']
# ['7849508', 'Denver', 'Diana DeGette']
# ['5153723', 'Denver', 'Diana DeGette']
# ['5158490', 'Denver', 'Diana DeGette']
# ['6308311', 'Denver', 'Diana DeGette']
# ['7847979', 'Denver', 'Diana DeGette']
# ['5114631', 'Denver', 'Diana DeGette']
# ['6919831', 'Denver', 'Diana DeGette']
# ['6035933', 'Denver', 'Diana DeGette']
# ['5265724', 'Denver', 'Diana DeGette']
# ['6319937', 'Denver', 'Diana DeGette']
# ['7179728', 'Denver', 'Diana DeGette']
# ['5185367', 'Denver', 'Diana DeGette']
# ['5982731', 'Denver', 'Diana DeGette']
# ['6071443', 'Denver', 'Diana DeGette']
# ['7439249', 'Denver', 'Diana DeGette']
# ['6637643', 'Denver', 'Diana DeGette']
# ['7274941', 'Denver', 'Diana DeGette']
# ['5469189', 'Denver', 'Diana DeGette']
# ['5580878', 'Denver', 'Diana DeGette']
# ['7377133', 'Denver', 'Diana DeGette']
# ['7112046', 'Denver', 'Diana DeGette']
# ['5617767', 'Denver', 'Diana DeGette']
# ['7700753', 'Denver', 'Diana DeGette']
# ['5968398', 'Denver', 'Diana DeGette']
# ['5655687', 'Denver', 'Diana DeGette']
# ['5823449', 'Denver', 'Diana DeGette']
# ['7935910', 'Denver', 'Diana DeGette']
# ['5115113', 'Denver', 'Diana DeGette']
# ['5276122', 'Denver', 'Diana DeGette']
# ['5208427', 'Denver', 'Diana DeGette']
# ['5497706', 'Denver', 'Diana DeGette']
# ['6014902', 'Denver', 'Diana DeGette']
# ['5236974', 'Denver', 'Diana DeGette']
# ['6297707', 'Denver', 'Diana DeGette']
# ['6133545', 'Denver', 'Diana DeGette']
# ['6248040', 'Denver', 'Diana DeGette']
# ['7271051', 'Denver', 'Diana DeGette']
# ['7100596', 'Denver', 'Diana DeGette']
# ['6747530', 'Denver', 'Diana DeGette']
# ['7942900', 'Denver', 'Diana DeGette']
# ['7914448', 'Denver', 'Diana DeGette']
# ['5354795', 'Denver', 'Diana DeGette']
# ['7305750', 'Denver', 'Diana DeGette']
# ['6931951', 'Denver', 'Diana DeGette']
# ['7672477', 'Denver', 'Diana DeGette']
# ['5065238', 'Denver', 'Diana DeGette']
# ['5862775', 'Denver', 'Diana DeGette']
# ['7653799', 'Denver', 'Diana DeGette']
# ['7668455', 'Denver', 'Diana DeGette']
# ['5751985', 'Denver', 'Diana DeGette']
# ['5107244', 'Denver', 'Diana DeGette']
# ['5422267', 'Denver', 'Diana DeGette']
# ['6330011', 'Denver', 'Diana DeGette']
# ['7196621', 'Denver', 'Diana DeGette']
# ['7841232', 'Denver', 'Diana DeGette']
# ['7871607', 'Denver', 'Diana DeGette']
# ['6778941', 'Denver', 'Diana DeGette']
# ['5804725', 'Denver', 'Diana DeGette']
# ['6670689', 'Denver', 'Diana DeGette']
# ['5728656', 'Denver', 'Diana DeGette']
# ['5781834', 'Denver', 'Diana DeGette']
# ['7551811', 'Denver', 'Diana DeGette']
# ['6283780', 'Denver', 'Diana DeGette']
# ['5779243', 'Denver', 'Diana DeGette']
# ['6960657', 'Denver', 'Diana DeGette']
# ['5657614', 'Denver', 'Diana DeGette']
# ['7391988', 'Denver', 'Diana DeGette']
# ['5210760', 'Denver', 'Diana DeGette']
# ['7022342', 'Denver', 'Diana DeGette']
# ['7870528', 'Denver', 'Diana DeGette']
# ['7349069', 'Denver', 'Diana DeGette']
# ['6702659', 'Denver', 'Diana DeGette']
# ['6093194', 'Denver', 'Diana DeGette']
# ['7697157', 'Denver', 'Diana DeGette']
# ['5327086', 'Denver', 'Diana DeGette']
# ['6180775', 'Denver', 'Diana DeGette']
# ['7528842', 'Denver', 'Diana DeGette']
# ['5277200', 'Denver', 'Diana DeGette']
# ['5791637', 'Denver', 'Diana DeGette']
# ['6797342', 'Denver', 'Diana DeGette']
# ['6122342', 'Denver', 'Diana DeGette']
# ['6290394', 'Denver', 'Diana DeGette']
# ['5469903', 'Denver', 'Diana DeGette']
# ['5732370', 'Denver', 'Diana DeGette']
# ['6244324', 'Denver', 'Diana DeGette']
# ['7401292', 'Denver', 'Diana DeGette']
# ['5551124', 'Denver', 'Diana DeGette']
# ['5909411', 'Denver', 'Diana DeGette']
# ['5651849', 'Denver', 'Diana DeGette']
# ['7714141', 'Denver', 'Diana DeGette']
# ['7624091', 'Denver', 'Diana DeGette']
# ['6986501', 'Denver', 'Diana DeGette']
# ['5629509', 'Denver', 'Diana DeGette']
# ['5920077', 'Denver', 'Diana DeGette']
# ['7624587', 'Denver', 'Diana DeGette']
# ['7933556', 'Denver', 'Diana DeGette']
# ['5676669', 'Denver', 'Diana DeGette']
# ['5309737', 'Denver', 'Diana DeGette']
# ['5877706', 'Denver', 'Diana DeGette']
# ['5838330', 'Denver', 'Diana DeGette']
# ['7465183', 'Denver', 'Diana DeGette']
# ['6312085', 'Denver', 'Diana DeGette']
# ['6025292', 'Denver', 'Diana DeGette']
# ['6717996', 'Denver', 'Diana DeGette']
# ['5524105', 'Denver', 'Diana DeGette']
# ['6186505', 'Denver', 'Diana DeGette']
# ['7950564', 'Denver', 'Diana DeGette']
# ['6020183', 'Denver', 'Diana DeGette']
# ['7501948', 'Denver', 'Diana DeGette']
# ['7009683', 'Denver', 'Diana DeGette']
# ['5367066', 'Denver', 'Diana DeGette']
# ['5020198', 'Denver', 'Diana DeGette']
# ['5367135', 'Denver', 'Diana DeGette']
# ['5297171', 'Denver', 'Diana DeGette']
# ['6798190', 'Denver', 'Diana DeGette']
# ['7472826', 'Denver', 'Diana DeGette']
# ['7771747', 'Denver', 'Diana DeGette']
# ['5628688', 'Denver', 'Diana DeGette']
# ['6443175', 'Denver', 'Diana DeGette']
# ['6147151', 'Denver', 'Diana DeGette']
# ['5144401', 'Denver', 'Diana DeGette']
# ['5222117', 'Denver', 'Diana DeGette']
# ['5850111', 'Denver', 'Diana DeGette']
# ['7628371', 'Denver', 'Diana DeGette']
# ['7319881', 'Denver', 'Diana DeGette']
# ['5578632', 'Denver', 'Diana DeGette']
# ['6010659', 'Denver', 'Diana DeGette']
# ['7858034', 'Denver', 'Diana DeGette']
# ['7496286', 'Denver', 'Diana DeGette']
# ['5057749', 'Denver', 'Diana DeGette']
# ['5177601', 'Denver', 'Diana DeGette']
# ['5216605', 'Denver', 'Diana DeGette']
# ['6409324', 'Denver', 'Diana DeGette']
# ['6265619', 'Denver', 'Diana DeGette']
# ['6913182', 'Denver', 'Diana DeGette']
# ['6419102', 'Denver', 'Diana DeGette']
# ['7192973', 'Denver', 'Diana DeGette']
# ['6932151', 'Denver', 'Diana DeGette']
# ['6223074', 'Denver', 'Diana DeGette']
# ['5734762', 'Denver', 'Diana DeGette']
# ['5282276', 'Denver', 'Diana DeGette']
# ['7692564', 'Denver', 'Diana DeGette']
# ['7084795', 'Denver', 'Diana DeGette']
# ['5172357', 'Denver', 'Diana DeGette']
# ['5759318', 'Denver', 'Diana DeGette']
# ['6172342', 'Denver', 'Diana DeGette']
# ['6717028', 'Denver', 'Diana DeGette']
# ['7212795', 'Denver', 'Diana DeGette']
# ['5447340', 'Denver', 'Diana DeGette']
# ['5734700', 'Denver', 'Diana DeGette']
# ['6109830', 'Denver', 'Diana DeGette']
# ['5159904', 'Denver', 'Diana DeGette']
# ['6241500', 'Denver', 'Diana DeGette']
# ['7163485', 'Denver', 'Diana DeGette']
# ['6217788', 'Denver', 'Diana DeGette']
# ['7776407', 'Denver', 'Diana DeGette']
# ['6574095', 'Denver', 'Diana DeGette']
# ['5104194', 'Denver', 'Diana DeGette']
# ['5537548', 'Denver', 'Diana DeGette']
# ['7805492', 'Denver', 'Diana DeGette']
# ['7796288', 'Denver', 'Diana DeGette']
# ['5503508', 'Denver', 'Diana DeGette']
# ['6157523', 'Denver', 'Diana DeGette']
# ['6536368', 'Denver', 'Diana DeGette']
# ['5379062', 'Denver', 'Diana DeGette']
# ['5717460', 'Denver', 'Diana DeGette']
# ['7892270', 'Denver', 'Diana DeGette']
# ['6677425', 'Denver', 'Diana DeGette']
# ['6445672', 'Denver', 'Diana DeGette']
# ['7702194', 'Denver', 'Diana DeGette']
# ['6535935', 'Denver', 'Diana DeGette']
# ['7833184', 'Denver', 'Diana DeGette']
# ['6380325', 'Denver', 'Diana DeGette']
# ['7132150', 'Denver', 'Diana DeGette']
# ['5898701', 'Denver', 'Diana DeGette']
# ['7221214', 'Denver', 'Diana DeGette']
# ['7984607', 'Denver', 'Diana DeGette']
# ['5057530', 'Denver', 'Diana DeGette']
# ['7630227', 'Denver', 'Diana DeGette']
# ['7694320', 'Denver', 'Diana DeGette']
# ['6035319', 'Denver', 'Diana DeGette']
# ['5812939', 'Denver', 'Diana DeGette']
# ['5478872', 'Denver', 'Diana DeGette']
# ['6101920', 'Denver', 'Diana DeGette']
# ['6950309', 'Denver', 'Diana DeGette']
# ['7799838', 'Denver', 'Diana DeGette']
# ['7412406', 'Denver', 'Diana DeGette']
# ['7636218', 'Denver', 'Diana DeGette']
# ['6262574', 'Denver', 'Diana DeGette']
# ['7222755', 'Denver', 'Diana DeGette']
# ['5949825', 'Denver', 'Diana DeGette']
# ['5028988', 'Denver', 'Diana DeGette']
# ['5852881', 'Denver', 'Diana DeGette']
# ['7870056', 'Denver', 'Diana DeGette']
# ['6466215', 'Denver', 'Diana DeGette']
# ['5541867', 'Denver', 'Diana DeGette']
# ['6982518', 'Denver', 'Diana DeGette']
# ['5799257', 'Denver', 'Diana DeGette']
# ['6304922', 'Denver', 'Diana DeGette']
# ['6706673', 'Denver', 'Diana DeGette']
# ['6580991', 'Denver', 'Diana DeGette']
# ['7906474', 'Denver', 'Diana DeGette']
# ['5361082', 'Denver', 'Diana DeGette']
# ['6383685', 'Denver', 'Diana DeGette']
# ['6945714', 'Denver', 'Diana DeGette']
# ['6666919', 'Denver', 'Diana DeGette']
# ['7282882', 'Denver', 'Diana DeGette']
# ['6148957', 'Denver', 'Diana DeGette']
# ['5540376', 'Denver', 'Diana DeGette']
# ['6620021', 'Denver', 'Diana DeGette']
# ['5991494', 'Denver', 'Diana DeGette']
# ['6049868', 'Denver', 'Diana DeGette']
# ['5716820', 'Denver', 'Diana DeGette']
# ['7443263', 'Denver', 'Diana DeGette']
# ['7319404', 'Denver', 'Diana DeGette']
# ['6391513', 'Denver', 'Diana DeGette']
# ['5622053', 'Denver', 'Diana DeGette']
# ['6912852', 'Denver', 'Diana DeGette']
# ['6598119', 'Denver', 'Diana DeGette']
# ['7663540', 'Denver', 'Diana DeGette']
# ['6538781', 'Denver', 'Diana DeGette']
# ['7241304', 'Denver', 'Diana DeGette']
# ['6993285', 'Denver', 'Diana DeGette']
# ['5159930', 'Denver', 'Diana DeGette']
# ['6606350', 'Denver', 'Diana DeGette']
# ['5516336', 'Denver', 'Diana DeGette']
# ['6075449', 'Denver', 'Diana DeGette']
# ['6123158', 'Denver', 'Diana DeGette']
# ['7737179', 'Denver', 'Diana DeGette']
# ['6299329', 'Denver', 'Diana DeGette']
# ['6454761', 'Denver', 'Diana DeGette']
# ['5088926', 'Denver', 'Diana DeGette']
# ['6739789', 'Denver', 'Diana DeGette']
# ['5286709', 'Denver', 'Diana DeGette']
# ['5907250', 'Denver', 'Diana DeGette']
# ['6845007', 'Denver', 'Diana DeGette']
# ['7157813', 'Denver', 'Diana DeGette']
# ['6351327', 'Denver', 'Diana DeGette']
# ['7429590', 'Denver', 'Diana DeGette']
# ['6517005', 'Denver', 'Diana DeGette']
# ['6659530', 'Denver', 'Diana DeGette']
# ['7110475', 'Denver', 'Diana DeGette']
# ['6870221', 'Denver', 'Diana DeGette']
# ['7696190', 'Denver', 'Diana DeGette']
# ['6323576', 'Denver', 'Diana DeGette']
# ['7708242', 'Denver', 'Diana DeGette']
# ['6159426', 'Denver', 'Diana DeGette']
# ['5699547', 'Denver', 'Diana DeGette']
# ['5397157', 'Denver', 'Diana DeGette']
# ['7510053', 'Denver', 'Diana DeGette']
# ['5357437', 'Denver', 'Diana DeGette']
# ['6937892', 'Denver', 'Diana DeGette']
# ['6966455', 'Denver', 'Diana DeGette']
# ['6139057', 'Denver', 'Diana DeGette']
# ['7627762', 'Denver', 'Diana DeGette']
# ['7373243', 'Denver', 'Diana DeGette']
# ['5289471', 'Denver', 'Diana DeGette']
# ['7649607', 'Denver', 'Diana DeGette']
# ['7638241', 'Denver', 'Diana DeGette']
# ['5765386', 'Denver', 'Diana DeGette']
# ['5621312', 'Denver', 'Diana DeGette']
# ['6002516', 'Denver', 'Diana DeGette']
# ['7641981', 'Denver', 'Diana DeGette']
# ['5911686', 'Denver', 'Diana DeGette']
# ['7071763', 'Denver', 'Diana DeGette']
# ['5771773', 'Denver', 'Diana DeGette']
# ['5963146', 'Denver', 'Diana DeGette']
# ['5891287', 'Denver', 'Diana DeGette']
# ['7035672', 'Denver', 'Diana DeGette']
# ['7801269', 'Denver', 'Diana DeGette']
# ['5231646', 'Denver', 'Diana DeGette']
# ['5663133', 'Denver', 'Diana DeGette']
# ['6259251', 'Denver', 'Diana DeGette']
# ['5109228', 'Denver', 'Diana DeGette']
# ['5107095', 'Denver', 'Diana DeGette']
# ['5679551', 'Denver', 'Diana DeGette']
# ['6791008', 'Denver', 'Diana DeGette']
# ['6435178', 'Denver', 'Diana DeGette']
# ['5845216', 'Denver', 'Diana DeGette']
# ['5535191', 'Denver', 'Diana DeGette']
# ['7737786', 'Denver', 'Diana DeGette']
# ['7655947', 'Denver', 'Diana DeGette']
# ['7412075', 'Denver', 'Diana DeGette']
# ['5902206', 'Denver', 'Diana DeGette']
# ['7131628', 'Denver', 'Diana DeGette']
# ['5023538', 'Denver', 'Diana DeGette']
# ['5065221', 'Denver', 'Diana DeGette']
# ['6902512', 'Denver', 'Diana DeGette']
# ['5984675', 'Denver', 'Diana DeGette']
# ['6939760', 'Denver', 'Diana DeGette']
# ['7492323', 'Denver', 'Diana DeGette']
# ['5242528', 'Denver', 'Diana DeGette']
# ['6438134', 'Denver', 'Diana DeGette']
# ['5862397', 'Denver', 'Diana DeGette']
# ['5631671', 'Denver', 'Diana DeGette']
# ['7448956', 'Denver', 'Diana DeGette']
# ['6824052', 'Denver', 'Diana DeGette']
# ['7881404', 'Denver', 'Diana DeGette']
# ['7356772', 'Denver', 'Diana DeGette']
# ['7781718', 'Denver', 'Diana DeGette']
# ['6279028', 'Denver', 'Diana DeGette']
# ['5482701', 'Denver', 'Diana DeGette']
# ...
# ['4796498', 'Arapahoe', 'Raymon Anthony Doane']
# ['4682356', 'Arapahoe', 'Raymon Anthony Doane']
# ['4462340', 'Arapahoe', 'Raymon Anthony Doane']
# ['4599862', 'Arapahoe', 'Raymon Anthony Doane']
# ['4122297', 'Arapahoe', 'Raymon Anthony Doane']
# ['4940598', 'Arapahoe', 'Raymon Anthony Doane']
# ['4672890', 'Arapahoe', 'Raymon Anthony Doane']
# ['4783819', 'Arapahoe', 'Raymon Anthony Doane']
# ['4181264', 'Arapahoe', 'Raymon Anthony Doane']
# ['4418030', 'Arapahoe', 'Raymon Anthony Doane']
# ['4297317', 'Arapahoe', 'Raymon Anthony Doane']
# ['4061422', 'Arapahoe', 'Raymon Anthony Doane']
# ['4441187', 'Arapahoe', 'Raymon Anthony Doane']
# ['4433237', 'Arapahoe', 'Raymon Anthony Doane']
# ['4586559', 'Arapahoe', 'Raymon Anthony Doane']
# ['4454150', 'Arapahoe', 'Raymon Anthony Doane']
# ['4010123', 'Arapahoe', 'Raymon Anthony Doane']
# ['4990821', 'Arapahoe', 'Raymon Anthony Doane']
# ['4439635', 'Arapahoe', 'Raymon Anthony Doane']
# ['4885455', 'Arapahoe', 'Raymon Anthony Doane']
# ['4999048', 'Arapahoe', 'Raymon Anthony Doane']
# ['4845287', 'Arapahoe', 'Raymon Anthony Doane']
# ['4427314', 'Arapahoe', 'Raymon Anthony Doane']
# ['4834878', 'Arapahoe', 'Raymon Anthony Doane']
# ['4242981', 'Arapahoe', 'Raymon Anthony Doane']
# ['4194260', 'Arapahoe', 'Raymon Anthony Doane']
# ['4267996', 'Arapahoe', 'Raymon Anthony Doane']
# ['4213145', 'Arapahoe', 'Raymon Anthony Doane']
# ['4897453', 'Arapahoe', 'Raymon Anthony Doane']
# ['4523223', 'Arapahoe', 'Raymon Anthony Doane']
# ['4265714', 'Arapahoe', 'Raymon Anthony Doane']
# ['4644022', 'Arapahoe', 'Raymon Anthony Doane']
# ['4877965', 'Arapahoe', 'Raymon Anthony Doane']
# ['4930170', 'Arapahoe', 'Raymon Anthony Doane']
# ['4860548', 'Arapahoe', 'Raymon Anthony Doane']
# ['4007952', 'Arapahoe', 'Raymon Anthony Doane']
# ['4549879', 'Arapahoe', 'Raymon Anthony Doane']
# ['4822687', 'Arapahoe', 'Raymon Anthony Doane']
# ['4612500', 'Arapahoe', 'Raymon Anthony Doane']
# ['4795823', 'Arapahoe', 'Raymon Anthony Doane']
# ['4456647', 'Arapahoe', 'Raymon Anthony Doane']
# ['4994109', 'Arapahoe', 'Raymon Anthony Doane']
# ['4032340', 'Arapahoe', 'Raymon Anthony Doane']
# ['4346134', 'Arapahoe', 'Raymon Anthony Doane']
# ['4199039', 'Arapahoe', 'Raymon Anthony Doane']
# ['4341580', 'Arapahoe', 'Raymon Anthony Doane']
# ['4883803', 'Arapahoe', 'Raymon Anthony Doane']
# ['4715712', 'Arapahoe', 'Raymon Anthony Doane']
# ['4215358', 'Arapahoe', 'Raymon Anthony Doane']
# ['4678964', 'Arapahoe', 'Raymon Anthony Doane']
# ['4361321', 'Arapahoe', 'Raymon Anthony Doane']
# ['4283796', 'Arapahoe', 'Raymon Anthony Doane']
# ['4940999', 'Arapahoe', 'Raymon Anthony Doane']
# ['4681240', 'Arapahoe', 'Raymon Anthony Doane']
# ['4394024', 'Arapahoe', 'Raymon Anthony Doane']
# ['4613456', 'Arapahoe', 'Raymon Anthony Doane']
# ['4504850', 'Arapahoe', 'Raymon Anthony Doane']
# ['4921457', 'Arapahoe', 'Raymon Anthony Doane']
# ['4911442', 'Arapahoe', 'Raymon Anthony Doane']
# ['4389090', 'Arapahoe', 'Raymon Anthony Doane']
# ['4020401', 'Arapahoe', 'Raymon Anthony Doane']
# ['4173631', 'Arapahoe', 'Raymon Anthony Doane']
# ['4377148', 'Arapahoe', 'Raymon Anthony Doane']
# ['4848309', 'Arapahoe', 'Raymon Anthony Doane']
# ['4852047', 'Arapahoe', 'Raymon Anthony Doane']
# ['4530115', 'Arapahoe', 'Raymon Anthony Doane']
# ['4017525', 'Arapahoe', 'Raymon Anthony Doane']
# ['4471703', 'Arapahoe', 'Raymon Anthony Doane']
# ['4323415', 'Arapahoe', 'Raymon Anthony Doane']
# ['4679963', 'Arapahoe', 'Raymon Anthony Doane']
# ['4758333', 'Arapahoe', 'Raymon Anthony Doane']
# ['4190272', 'Arapahoe', 'Raymon Anthony Doane']
# ['4600777', 'Arapahoe', 'Raymon Anthony Doane']
# ['4069570', 'Arapahoe', 'Raymon Anthony Doane']
# ['4164389', 'Arapahoe', 'Raymon Anthony Doane']
# ['4866879', 'Arapahoe', 'Raymon Anthony Doane']
# ['4142531', 'Arapahoe', 'Raymon Anthony Doane']
# ['4998549', 'Arapahoe', 'Raymon Anthony Doane']
# ['4550308', 'Arapahoe', 'Raymon Anthony Doane']
# ['4216224', 'Arapahoe', 'Raymon Anthony Doane']
# ['4770615', 'Arapahoe', 'Raymon Anthony Doane']
# ['4558224', 'Arapahoe', 'Raymon Anthony Doane']
# ['4129798', 'Arapahoe', 'Raymon Anthony Doane']
# ['4984911', 'Arapahoe', 'Raymon Anthony Doane']
# ['4826257', 'Arapahoe', 'Raymon Anthony Doane']
# ['4625773', 'Arapahoe', 'Raymon Anthony Doane']
# ['4937962', 'Arapahoe', 'Raymon Anthony Doane']
# ['4024880', 'Arapahoe', 'Raymon Anthony Doane']
# ['4345064', 'Arapahoe', 'Raymon Anthony Doane']
# ['4007820', 'Arapahoe', 'Raymon Anthony Doane']
# ['4486359', 'Arapahoe', 'Raymon Anthony Doane']
# ['4452656', 'Arapahoe', 'Raymon Anthony Doane']
# ['4522743', 'Arapahoe', 'Raymon Anthony Doane']
# ['4905789', 'Arapahoe', 'Raymon Anthony Doane']
# ['4557263', 'Arapahoe', 'Raymon Anthony Doane']
# ['4128726', 'Arapahoe', 'Raymon Anthony Doane']
# ['4672208', 'Arapahoe', 'Raymon Anthony Doane']
# ['4766476', 'Arapahoe', 'Raymon Anthony Doane']
# ['4157993', 'Arapahoe', 'Raymon Anthony Doane']
# ['4377061', 'Arapahoe', 'Raymon Anthony Doane']
# ['4661160', 'Arapahoe', 'Raymon Anthony Doane']
# ['4134958', 'Arapahoe', 'Raymon Anthony Doane']
# ['4180188', 'Arapahoe', 'Raymon Anthony Doane']
# ['4620543', 'Arapahoe', 'Raymon Anthony Doane']
# ['4182292', 'Arapahoe', 'Raymon Anthony Doane']
# ['4357236', 'Arapahoe', 'Raymon Anthony Doane']
# ['4929895', 'Arapahoe', 'Raymon Anthony Doane']
# ['4206793', 'Arapahoe', 'Raymon Anthony Doane']
# ['4937467', 'Arapahoe', 'Raymon Anthony Doane']
# ['4559505', 'Arapahoe', 'Raymon Anthony Doane']
# ['4329385', 'Arapahoe', 'Raymon Anthony Doane']
# ['4652139', 'Arapahoe', 'Raymon Anthony Doane']
# ['4281390', 'Arapahoe', 'Raymon Anthony Doane']
# ['4947191', 'Arapahoe', 'Raymon Anthony Doane']
# ['4971995', 'Arapahoe', 'Raymon Anthony Doane']
# ['4718404', 'Arapahoe', 'Raymon Anthony Doane']
# ['4048902', 'Arapahoe', 'Raymon Anthony Doane']
# ['4092594', 'Arapahoe', 'Raymon Anthony Doane']
# ['4048048', 'Arapahoe', 'Raymon Anthony Doane']
# ['4697555', 'Arapahoe', 'Raymon Anthony Doane']
# ['4985428', 'Arapahoe', 'Raymon Anthony Doane']
# ['4211377', 'Arapahoe', 'Raymon Anthony Doane']
# ['4733358', 'Arapahoe', 'Raymon Anthony Doane']
# ['4318943', 'Arapahoe', 'Raymon Anthony Doane']
# ['4843025', 'Arapahoe', 'Raymon Anthony Doane']
# ['4706075', 'Arapahoe', 'Raymon Anthony Doane']
# ['4315708', 'Arapahoe', 'Raymon Anthony Doane']
# ['4146969', 'Arapahoe', 'Raymon Anthony Doane']
# ['4714620', 'Arapahoe', 'Raymon Anthony Doane']
# ['4581948', 'Arapahoe', 'Raymon Anthony Doane']
# ['4614078', 'Arapahoe', 'Raymon Anthony Doane']
# ['4455648', 'Arapahoe', 'Raymon Anthony Doane']
# ['4803824', 'Arapahoe', 'Raymon Anthony Doane']
# ['4100880', 'Arapahoe', 'Raymon Anthony Doane']
# ['4951577', 'Arapahoe', 'Raymon Anthony Doane']
# ['4120717', 'Arapahoe', 'Raymon Anthony Doane']
# ['4337808', 'Arapahoe', 'Raymon Anthony Doane']
# ['4184236', 'Arapahoe', 'Raymon Anthony Doane']
# ['4233592', 'Arapahoe', 'Raymon Anthony Doane']
# ['4990015', 'Arapahoe', 'Raymon Anthony Doane']
# ['4816080', 'Arapahoe', 'Raymon Anthony Doane']
# ['4798484', 'Arapahoe', 'Raymon Anthony Doane']
# ['4576252', 'Arapahoe', 'Raymon Anthony Doane']
# ['4273716', 'Arapahoe', 'Raymon Anthony Doane']
# ['4998530', 'Arapahoe', 'Raymon Anthony Doane']
# ['4014358', 'Arapahoe', 'Raymon Anthony Doane']
# ['4142338', 'Arapahoe', 'Raymon Anthony Doane']
# ['4837906', 'Arapahoe', 'Raymon Anthony Doane']
# ['4199074', 'Arapahoe', 'Raymon Anthony Doane']
# ['4926700', 'Arapahoe', 'Raymon Anthony Doane']
# ['4896490', 'Arapahoe', 'Raymon Anthony Doane']
# ['4998027', 'Arapahoe', 'Raymon Anthony Doane']
# ['4218304', 'Arapahoe', 'Raymon Anthony Doane']
# ['4895093', 'Arapahoe', 'Raymon Anthony Doane']
# ['4325572', 'Arapahoe', 'Raymon Anthony Doane']
# ['4474399', 'Arapahoe', 'Raymon Anthony Doane']
# ['4839809', 'Arapahoe', 'Raymon Anthony Doane']
# ['4650616', 'Arapahoe', 'Raymon Anthony Doane']
# ['4651631', 'Arapahoe', 'Raymon Anthony Doane']
# ['4576932', 'Arapahoe', 'Raymon Anthony Doane']
# ['4998146', 'Arapahoe', 'Raymon Anthony Doane']
# ['4281646', 'Arapahoe', 'Raymon Anthony Doane']
# ['4451055', 'Arapahoe', 'Raymon Anthony Doane']
# ['4107619', 'Arapahoe', 'Raymon Anthony Doane']
# ['4247842', 'Arapahoe', 'Raymon Anthony Doane']
# ['4904115', 'Arapahoe', 'Raymon Anthony Doane']
# ['4465183', 'Arapahoe', 'Raymon Anthony Doane']
# ['4261961', 'Arapahoe', 'Raymon Anthony Doane']
# ['4831201', 'Arapahoe', 'Raymon Anthony Doane']
# ['4284880', 'Arapahoe', 'Raymon Anthony Doane']
# ['4099702', 'Arapahoe', 'Raymon Anthony Doane']
# ['4046886', 'Arapahoe', 'Raymon Anthony Doane']
# ['4070862', 'Arapahoe', 'Raymon Anthony Doane']
# ['4781660', 'Arapahoe', 'Raymon Anthony Doane']
# ['4636318', 'Arapahoe', 'Raymon Anthony Doane']
# ['4234290', 'Arapahoe', 'Raymon Anthony Doane']
# ['4779834', 'Arapahoe', 'Raymon Anthony Doane']
# ['4993576', 'Arapahoe', 'Raymon Anthony Doane']
# ['4062204', 'Arapahoe', 'Raymon Anthony Doane']
# ['4299367', 'Arapahoe', 'Raymon Anthony Doane']
# ['4499594', 'Arapahoe', 'Raymon Anthony Doane']
# ['4392331', 'Arapahoe', 'Raymon Anthony Doane']
# ['4487029', 'Arapahoe', 'Raymon Anthony Doane']
# ['4669338', 'Arapahoe', 'Raymon Anthony Doane']
# ['4951149', 'Arapahoe', 'Raymon Anthony Doane']
# ['4085583', 'Arapahoe', 'Raymon Anthony Doane']
# ['4469010', 'Arapahoe', 'Raymon Anthony Doane']
# ['4488651', 'Arapahoe', 'Raymon Anthony Doane']
# ['4637668', 'Arapahoe', 'Raymon Anthony Doane']
# ['4427627', 'Arapahoe', 'Raymon Anthony Doane']
# ['4002581', 'Arapahoe', 'Raymon Anthony Doane']
# ['4618885', 'Arapahoe', 'Raymon Anthony Doane']
# ['4471641', 'Arapahoe', 'Raymon Anthony Doane']
# ['4813849', 'Arapahoe', 'Raymon Anthony Doane']
# ['4376070', 'Arapahoe', 'Raymon Anthony Doane']
# ['4874276', 'Arapahoe', 'Raymon Anthony Doane']
# ['4828231', 'Arapahoe', 'Raymon Anthony Doane']
# ['4440381', 'Arapahoe', 'Raymon Anthony Doane']
# ['4461992', 'Arapahoe', 'Raymon Anthony Doane']
# ['4409454', 'Arapahoe', 'Raymon Anthony Doane']
# ['4813746', 'Arapahoe', 'Raymon Anthony Doane']
# ['4348962', 'Arapahoe', 'Raymon Anthony Doane']
# ['4707185', 'Arapahoe', 'Raymon Anthony Doane']
# ['4739828', 'Arapahoe', 'Raymon Anthony Doane']
# ['4441763', 'Arapahoe', 'Raymon Anthony Doane']
# ['4127601', 'Arapahoe', 'Raymon Anthony Doane']
# ['4057129', 'Arapahoe', 'Raymon Anthony Doane']
# ['4779538', 'Arapahoe', 'Raymon Anthony Doane']
# ['4352916', 'Arapahoe', 'Raymon Anthony Doane']
# ['4661453', 'Arapahoe', 'Raymon Anthony Doane']
# ['4882641', 'Arapahoe', 'Raymon Anthony Doane']
# ['4437582', 'Arapahoe', 'Raymon Anthony Doane']
# ['4854964', 'Arapahoe', 'Raymon Anthony Doane']
# ['4193654', 'Arapahoe', 'Raymon Anthony Doane']
# ['4479857', 'Arapahoe', 'Raymon Anthony Doane']
# ['4546091', 'Arapahoe', 'Raymon Anthony Doane']
# ['4988526', 'Arapahoe', 'Raymon Anthony Doane']
# ['4831244', 'Arapahoe', 'Raymon Anthony Doane']
# ['4406050', 'Arapahoe', 'Raymon Anthony Doane']
# ['4486374', 'Arapahoe', 'Raymon Anthony Doane']
# ['4388382', 'Arapahoe', 'Raymon Anthony Doane']
# ['4615979', 'Arapahoe', 'Raymon Anthony Doane']
# ['4454889', 'Arapahoe', 'Raymon Anthony Doane']
# ['4016923', 'Arapahoe', 'Raymon Anthony Doane']
# ['4003895', 'Arapahoe', 'Raymon Anthony Doane']
# ['4760373', 'Arapahoe', 'Raymon Anthony Doane']
# ['4833860', 'Arapahoe', 'Raymon Anthony Doane']
# ['4366605', 'Arapahoe', 'Raymon Anthony Doane']
# ['4742191', 'Arapahoe', 'Raymon Anthony Doane']
# ['4262583', 'Arapahoe', 'Raymon Anthony Doane']
# ['4199469', 'Arapahoe', 'Raymon Anthony Doane']
# ['4242507', 'Arapahoe', 'Raymon Anthony Doane']
# ['4641540', 'Arapahoe', 'Raymon Anthony Doane']
# ['4808428', 'Arapahoe', 'Raymon Anthony Doane']
# ['4055720', 'Arapahoe', 'Raymon Anthony Doane']
# ['4147053', 'Arapahoe', 'Raymon Anthony Doane']
# ['4343569', 'Arapahoe', 'Raymon Anthony Doane']
# ['4954475', 'Arapahoe', 'Raymon Anthony Doane']
# ['4299776', 'Arapahoe', 'Raymon Anthony Doane']
# ['4324102', 'Arapahoe', 'Raymon Anthony Doane']
# ['4979876', 'Arapahoe', 'Raymon Anthony Doane']
# ['4087498', 'Arapahoe', 'Raymon Anthony Doane']
# ['4937607', 'Arapahoe', 'Raymon Anthony Doane']
# ['4226549', 'Arapahoe', 'Raymon Anthony Doane']
# ['4015879', 'Arapahoe', 'Raymon Anthony Doane']
# ['4219650', 'Arapahoe', 'Raymon Anthony Doane']
# ['4389593', 'Arapahoe', 'Raymon Anthony Doane']
# ['4283466', 'Arapahoe', 'Raymon Anthony Doane']
# ['4419041', 'Arapahoe', 'Raymon Anthony Doane']
# ['4381655', 'Arapahoe', 'Raymon Anthony Doane']
# ['4996434', 'Arapahoe', 'Raymon Anthony Doane']
# ['4041068', 'Arapahoe', 'Raymon Anthony Doane']
# ['4475095', 'Arapahoe', 'Raymon Anthony Doane']
# ['4020902', 'Arapahoe', 'Raymon Anthony Doane']
# ['4189809', 'Arapahoe', 'Raymon Anthony Doane']
# ['4575367', 'Arapahoe', 'Raymon Anthony Doane']
# ['4968642', 'Arapahoe', 'Raymon Anthony Doane']
# ['4937721', 'Arapahoe', 'Raymon Anthony Doane']
# ['4800246', 'Arapahoe', 'Raymon Anthony Doane']
# ['4272418', 'Arapahoe', 'Raymon Anthony Doane']
# ['4162862', 'Arapahoe', 'Raymon Anthony Doane']
# ['4667920', 'Arapahoe', 'Raymon Anthony Doane']
# ['4693629', 'Arapahoe', 'Raymon Anthony Doane']
# ['4754667', 'Arapahoe', 'Raymon Anthony Doane']
# ['4904042', 'Arapahoe', 'Raymon Anthony Doane']
# ['4018288', 'Arapahoe', 'Raymon Anthony Doane']
# ['4897841', 'Arapahoe', 'Raymon Anthony Doane']
# ['4842870', 'Arapahoe', 'Raymon Anthony Doane']
# ['4431131', 'Arapahoe', 'Raymon Anthony Doane']
# ['4673728', 'Arapahoe', 'Raymon Anthony Doane']
# ['4858679', 'Arapahoe', 'Raymon Anthony Doane']
# ['4445637', 'Arapahoe', 'Raymon Anthony Doane']
# ['4509729', 'Arapahoe', 'Raymon Anthony Doane']
# ['4300765', 'Arapahoe', 'Raymon Anthony Doane']
# ['4052509', 'Arapahoe', 'Raymon Anthony Doane']
# ['4679291', 'Arapahoe', 'Raymon Anthony Doane']
# ['4776401', 'Arapahoe', 'Raymon Anthony Doane']
# ['4615704', 'Arapahoe', 'Raymon Anthony Doane']
# ['4729414', 'Arapahoe', 'Raymon Anthony Doane']
# ['4409601', 'Arapahoe', 'Raymon Anthony Doane']
# ['4071549', 'Arapahoe', 'Raymon Anthony Doane']
# ['4904129', 'Arapahoe', 'Raymon Anthony Doane']
# ['4912362', 'Arapahoe', 'Raymon Anthony Doane']
# ['4450112', 'Arapahoe', 'Raymon Anthony Doane']
# ['4159732', 'Arapahoe', 'Raymon Anthony Doane']
# ['4001660', 'Arapahoe', 'Raymon Anthony Doane']
# ['4418480', 'Arapahoe', 'Raymon Anthony Doane']
# ['4639364', 'Arapahoe', 'Raymon Anthony Doane']
# ['4635462', 'Arapahoe', 'Raymon Anthony Doane']
# ['4385557', 'Arapahoe', 'Raymon Anthony Doane']
# ['4658774', 'Arapahoe', 'Raymon Anthony Doane']
# ['4727148', 'Arapahoe', 'Raymon Anthony Doane']
# ['4400079', 'Arapahoe', 'Raymon Anthony Doane']
# ['4795809', 'Arapahoe', 'Raymon Anthony Doane']
# ['4961255', 'Arapahoe', 'Raymon Anthony Doane']
# ['4461504', 'Arapahoe', 'Raymon Anthony Doane']
# ['4953248', 'Arapahoe', 'Raymon Anthony Doane']
# ['4076232', 'Arapahoe', 'Raymon Anthony Doane']
# ['4847009', 'Arapahoe', 'Raymon Anthony Doane']
# ['4287085', 'Arapahoe', 'Raymon Anthony Doane']
# ['4770742', 'Arapahoe', 'Raymon Anthony Doane']
# ['4714965', 'Arapahoe', 'Raymon Anthony Doane']
# ['4981502', 'Arapahoe', 'Raymon Anthony Doane']
# ['4545560', 'Arapahoe', 'Raymon Anthony Doane']
# ['4723588', 'Arapahoe', 'Raymon Anthony Doane']
# ['4965626', 'Arapahoe', 'Raymon Anthony Doane']
# ['4298703', 'Arapahoe', 'Raymon Anthony Doane']
# ['4472094', 'Arapahoe', 'Raymon Anthony Doane']
# ['4842303', 'Arapahoe', 'Raymon Anthony Doane']
# ['4553822', 'Arapahoe', 'Raymon Anthony Doane']
# ['4358009', 'Arapahoe', 'Raymon Anthony Doane']
# ['4612998', 'Arapahoe', 'Raymon Anthony Doane']
# ['4210260', 'Arapahoe', 'Raymon Anthony Doane']
# ['4084395', 'Arapahoe', 'Raymon Anthony Doane']
# ['4033307', 'Arapahoe', 'Raymon Anthony Doane']
# ['4713121', 'Arapahoe', 'Raymon Anthony Doane']
# ['4557390', 'Arapahoe', 'Raymon Anthony Doane']
# ['4945313', 'Arapahoe', 'Raymon Anthony Doane']
# ['4151546', 'Arapahoe', 'Raymon Anthony Doane']
# ['4847858', 'Arapahoe', 'Raymon Anthony Doane']
# ['4370556', 'Arapahoe', 'Raymon Anthony Doane']
# ['4221692', 'Arapahoe', 'Raymon Anthony Doane']
# ['4704054', 'Arapahoe', 'Raymon Anthony Doane']
# ['4762851', 'Arapahoe', 'Raymon Anthony Doane']
# ['4678093', 'Arapahoe', 'Raymon Anthony Doane']
# ['4196905', 'Arapahoe', 'Raymon Anthony Doane']
# ['4299985', 'Arapahoe', 'Raymon Anthony Doane']
# ['4620283', 'Arapahoe', 'Raymon Anthony Doane']
# ['4714953', 'Arapahoe', 'Raymon Anthony Doane']
# ['4497542', 'Arapahoe', 'Raymon Anthony Doane']
# ['4085849', 'Arapahoe', 'Raymon Anthony Doane']
# ['4592018', 'Arapahoe', 'Raymon Anthony Doane']
# ['4660518', 'Arapahoe', 'Raymon Anthony Doane']
# 369711
